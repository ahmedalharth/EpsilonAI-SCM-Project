# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Supply-Chain-Management" data-toc-modified-id="Supply-Chain-Management-1"><span class="toc-item-num">1&nbsp;&nbsp;</span><strong>Supply Chain Management</strong></a></span><ul class="toc-item"><li><span><a href="#About-The-Data" data-toc-modified-id="About-The-Data-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>About The Data</a></span></li><li><span><a href="#Objective" data-toc-modified-id="Objective-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Objective</a></span></li></ul></li><li><span><a href="#Importing-libraries" data-toc-modified-id="Importing-libraries-2"><span class="toc-item-num">2&nbsp;&nbsp;</span><strong>Importing libraries</strong></a></span></li><li><span><a href="#Read-and-Exploare-the-data" data-toc-modified-id="Read-and-Exploare-the-data-3"><span class="toc-item-num">3&nbsp;&nbsp;</span><strong>Read and Exploare the data</strong></a></span><ul class="toc-item"><li><span><a href="#Missing-Values" data-toc-modified-id="Missing-Values-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Missing Values</a></span></li></ul></li><li><span><a href="#Exploratory-Data-Analysis" data-toc-modified-id="Exploratory-Data-Analysis-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Exploratory Data Analysis</a></span><ul class="toc-item"><li><span><a href="#Univariate-Analysis" data-toc-modified-id="Univariate-Analysis-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span><strong>Univariate Analysis</strong></a></span><ul class="toc-item"><li><span><a href="#Catogerical-Features" data-toc-modified-id="Catogerical-Features-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span><strong>Catogerical Features</strong></a></span></li><li><span><a href="#Numerical-features" data-toc-modified-id="Numerical-features-4.1.2"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span><strong>Numerical features</strong></a></span></li><li><span><a href="#Outliers-Analysis" data-toc-modified-id="Outliers-Analysis-4.1.3"><span class="toc-item-num">4.1.3&nbsp;&nbsp;</span>Outliers Analysis</a></span></li></ul></li><li><span><a href="#Bivariate-Analysis" data-toc-modified-id="Bivariate-Analysis-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span><strong>Bivariate Analysis</strong></a></span><ul class="toc-item"><li><span><a href="#Categorical-Chi_Squar-Test-of-Independence" data-toc-modified-id="Categorical-Chi_Squar-Test-of-Independence-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span><strong>Categorical Chi_Squar Test of Independence</strong></a></span></li><li><span><a href="#Pairwise-Correlation-with-the-Target-variable-and-for-numerical-variables" data-toc-modified-id="Pairwise-Correlation-with-the-Target-variable-and-for-numerical-variables-4.2.2"><span class="toc-item-num">4.2.2&nbsp;&nbsp;</span><strong>Pairwise Correlation with the Target variable and for numerical variables</strong></a></span></li></ul></li></ul></li><li><span><a href="#More-Data-for-training-with-SDV-library" data-toc-modified-id="More-Data-for-training-with-SDV-library-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>More Data for training with SDV library</a></span></li><li><span><a href="#Data-spliting" data-toc-modified-id="Data-spliting-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Data spliting</a></span></li><li><span><a href="#Feature-Engineering" data-toc-modified-id="Feature-Engineering-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Feature Engineering</a></span></li><li><span><a href="#Data-Preprocessing" data-toc-modified-id="Data-Preprocessing-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Data Preprocessing</a></span></li><li><span><a href="#Feature-Selection" data-toc-modified-id="Feature-Selection-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Feature Selection</a></span></li><li><span><a href="#Modeling" data-toc-modified-id="Modeling-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Modeling</a></span><ul class="toc-item"><li><span><a href="#Model-selection" data-toc-modified-id="Model-selection-10.1"><span class="toc-item-num">10.1&nbsp;&nbsp;</span>Model selection</a></span></li></ul></li></ul></div>

# %% [markdown]
# # **Supply Chain Management**
#
# **Predictive Analytics for Sustainable Supply Chain Management Using Machine Learning**

# %% [markdown]
# ## About The Data
#
# * **SCM Dataset with Green Logistics**
#
# `The dataset titled "SCM Dataset with Green Logistics" comprises a comprehensive collection of data from various companies, detailing their supply chain management (SCM) practices, performance metrics, and green logistics initiatives.
# `
# * **Data source** [Kaggle](https://www.kaggle.com/datasets/lastman0800/supply-chain-management/data)

# %% [markdown]
# ## Objective
# The primary objective of this project is to develop a machine learning model that predicts the **Supply Chain Risk (%)** of companies based on their supply chain management (SCM) practices, technology utilization, and sustainability efforts. By accurately forecasting Supply Chain Risk ratio, the model will help companies optimize their supply chain operations, reduce costs, and enhance overall performance.
#
# **Develop a Predictive Model for Supply Chain Risk**
# * `Use machine learning algorithms to predict the Supply Chain Risk ratio based on variables like Agile SCM, Lean Manufacturing, Supplier Count, Recycling Rate, and Use of Renewable Energy.`

# %% [markdown]
# # **Importing libraries**

# %%
# !pip install pingouin

# %%
# %pip install sdv

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt
import pingouin as pg
pd.plotting.register_matplotlib_converters()
# %matplotlib inline
from IPython. display import display
from itertools import combinations
from collections import Counter


# pre_preprocessing
from sklearn.compose import ColumnTransformer
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import OneHotEncoder, LabelEncoder , StandardScaler , MinMaxScaler,PolynomialFeatures

import sklearn.feature_selection


# Resampling
from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler

# Valdiation
from sklearn.model_selection import StratifiedShuffleSplit , StratifiedKFold , GroupKFold
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold

# Modeling
from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression 
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor


# Metrics
from sklearn.model_selection import cross_val_score 
from sklearn.metrics import r2_score , median_absolute_error , mean_squared_error

import warnings
warnings.filterwarnings('ignore')

#display all column of df 
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None) 
# to format the scientific presntastion of numbers 
pd.options.display.float_format = '{:.2f}'.format

# %% [markdown]
# # **Read and Exploare the data**

# %%
# read the data
df = pd.read_excel('SCM_Dataset_Updated_with_Green_Logistics.xlsx', sheet_name='Sheet1')

# %%
display(df.head())
print('Data Shape =>',df.shape)
# Out:
#   Company Name       SCM Practices  Supplier Count  Inventory Turnover Ratio  \
# 0        Apple           Agile SCM          300.00                      7.00
# 1    Microsoft  Lean Manufacturing          200.00                      5.20
# 2       Google       Cross-Docking        20000.00                      7.50
# 3       Amazon           Agile SCM          500.00                     10.50
# 4     Facebook  Lean Manufacturing          100.00                      5.80
#
#    Lead Time (days)  Order Fulfillment Rate (%)  Customer Satisfaction (%)  \
# 0              8.00                       94.00                      91.00
# 1             15.00                       91.00                      89.00
# 2              4.00                       95.00                      90.00
# 3             15.00                       95.00                      90.00
# 4             12.00                       89.00                      88.00
#
# ...

# %%
# Our Target variable
Target = "Supply Chain Risk (%)"

# %% [markdown]
# `The dataset records the technology utilized by each company, such as ERP, AI, Robotics, and Blockchain, and evaluates their Environmental Impact Score, Supply Chain Agility, Sustainability Practices, and Supply Chain Complexity Index. Financial metrics like Cost of Goods Sold (COGS), Operational Efficiency Score, Revenue Growth Rate, and Supply Chain Risk (%) `

# %%
# Information about the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 29 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Company Name                           999 non-null    object
#  1   SCM Practices                          999 non-null    object
#  2   Supplier Count                         999 non-null    float64
#  3   Inventory Turnover Ratio               999 non-null    float64
#  4   Lead Time (days)                       999 non-null    float64
#  5   Order Fulfillment Rate (%)             999 non-null    float64
#  6   Customer Satisfaction (%)              999 non-null    float64
#  7   Technology Utilized                    999 non-null    object
#  8   Environmental Impact Score             89 non-null     float64
#  9   Supply Chain Agility                   999 non-null    object
# ...

# %%
# Cost of Goods Sold (COGS) variable to float
df['Cost of Goods Sold (COGS)'] = df['Cost of Goods Sold (COGS)'].apply(func=lambda x: float(str(x).replace('$', '').replace(',', '').replace('B', '')))

# %%
# Summary statistics
def highlight_cols(x):
    return ['background-color: lightblue' if col in ['mean', '50%'] else '' for col in x.index]
display(df.describe().T.style.apply(highlight_cols, axis=1))
# Out:
# <style type="text/css">
# #T_d4fa4_row0_col1, #T_d4fa4_row0_col5, #T_d4fa4_row1_col1, #T_d4fa4_row1_col5, #T_d4fa4_row2_col1, #T_d4fa4_row2_col5, #T_d4fa4_row3_col1, #T_d4fa4_row3_col5, #T_d4fa4_row4_col1, #T_d4fa4_row4_col5, #T_d4fa4_row5_col1, #T_d4fa4_row5_col5, #T_d4fa4_row6_col1, #T_d4fa4_row6_col5, #T_d4fa4_row7_col1, #T_d4fa4_row7_col5, #T_d4fa4_row8_col1, #T_d4fa4_row8_col5, #T_d4fa4_row9_col1, #T_d4fa4_row9_col5, #T_d4fa4_row10_col1, #T_d4fa4_row10_col5, #T_d4fa4_row11_col1, #T_d4fa4_row11_col5, #T_d4fa4_row12_col1, #T_d4fa4_row12_col5, #T_d4fa4_row13_col1, #T_d4fa4_row13_col5, #T_d4fa4_row14_col1, #T_d4fa4_row14_col5, #T_d4fa4_row15_col1, #T_d4fa4_row15_col5, #T_d4fa4_row16_col1, #T_d4fa4_row16_col5, #T_d4fa4_row17_col1, #T_d4fa4_row17_col5, #T_d4fa4_row18_col1, #T_d4fa4_row18_col5, #T_d4fa4_row19_col1, #T_d4fa4_row19_col5, #T_d4fa4_row20_col1, #T_d4fa4_row20_col5 {
#   background-color: lightblue;
# }
# </style>
# <table id="T_d4fa4">
#   <thead>
#     <tr>
# ...

# %% [markdown]
# * `Almost Normaly distributed (mean ≈ median) in all expect the Total Implementation Cost`
# * `Total Implementaion Cost has negative values!`

# %% [markdown]
# ## Missing Values

# %%
# Missing values
df.isnull().sum()
# Out:
# Company Name                               1
# SCM Practices                              1
# Supplier Count                             1
# Inventory Turnover Ratio                   1
# Lead Time (days)                           1
# Order Fulfillment Rate (%)                 1
# Customer Satisfaction (%)                  1
# Technology Utilized                        1
# Environmental Impact Score               911
# Supply Chain Agility                       1
# Supplier Lead Time Variability (days)      1
# Inventory Accuracy (%)                     1
# Transportation Cost Efficiency (%)         1
# Supply Chain Integration Level             1
# Sustainability Practices                   1
# Supply Chain Complexity Index              1
# Cost of Goods Sold (COGS)                  1
# Operational Efficiency Score               1
# Revenue Growth Rate out of (15)            1
# Supply Chain Risk (%)                      1
# Supplier Collaboration Level               1
# ...

# %% [markdown]
# * `911 out of 1000 missing point in the Environmental Impact Score variable!.`
# * **NOTE: We can extract the Enviromental Impcat Score variable by combining various environmental factors into a single composite score.**

# %%
# Drop missing data
df.drop("Environmental Impact Score" ,axis=1 , inplace = True)
df.dropna(axis=0 , inplace=True)
print("Data dim:",df.shape)
# Out:
# Data dim: (999, 28)

# %% [markdown]
# # Exploratory Data Analysis
#
# `We gonna dive into the data and detect errors and mismatches, then correct them for further analysis and preprocessing`

# %%
# Devide the features into catogrical and numerical features.
cat = df.select_dtypes(include="O").columns.to_list()
num = [i for i in df.columns if i not in cat]

# %% [markdown]
# ## **Univariate Analysis**

# %% [markdown]
# ### **Catogerical Features**

# %%
df[cat].describe().T
# Out:
#                                count unique                  top freq
# Company Name                     999    777             Pep Boys    6
# SCM Practices                    999      8   Lean Manufacturing  326
# Technology Utilized              999      5  ERP, AI, Blockchain  697
# Supply Chain Agility             999      2                 High  841
# Supply Chain Integration Level   999      2                 High  807
# Sustainability Practices         999      1             Advanced  999
# Supply Chain Complexity Index    999      3               Medium  586
# Supplier Collaboration Level     999      2                 High  684

# %% [markdown]
# * `It seem like there is some errors in the categorical features and duplications in the companies names, that should be fixed along the walk!`

# %% [markdown]
# * **Sustainability Practices**

# %%
# Drope the Sustainability Practices since it have 1 unique value.
df.drop("Sustainability Practices", axis=1, inplace = True)
cat.remove("Sustainability Practices")
print("Data dim:",df.shape)
# Out:
# Data dim: (999, 27)

# %% [markdown]
# * **Company Name**

# %%
# Duplicated companies = 222
df['Company Name'].duplicated().value_counts()
# Out:
# Company Name
# False    777
# True     222
# Name: count, dtype: int64

# %% [markdown]
# * `To fix this we well group by the company name then take the mean of the numerical data and The mode of the categorical data`

# %%
# grouping by company df.groupby('Group')['Category'].agg(lambda x: x.mode()[0]
df = pd.concat([df.groupby('Company Name')[cat].agg(lambda x: x.mode()[0]) ,df.groupby("Company Name")[num].mean()], axis=1)

print("Data dim:",df.shape)
# Out:
# Data dim: (777, 27)

# %% [markdown]
# * **Technology Utilized**

# %%
# duplication in the Technology Utilized
display(df["Technology Utilized"].value_counts())
# Out:
# Technology Utilized
# ERP, AI, Blockchain         556
# ERP, AI, Robotics           112
# AI, ERP, Blockchain          54
# ERP, JIT, Robotics           28
# AI, Robotics, Blockchain     27
# Name: count, dtype: int64

# %% [markdown]
# `[AI, ERP, Blockchain] == [ERP, AI, Blockchain]!`

# %%
# Apply standrization to the 'Technology Utilized' column
df['Technology Utilized'] = df['Technology Utilized'].apply(lambda x: ', '.join(sorted(x.split(', '))))
display(df['Technology Utilized'].value_counts())
# Out:
# Technology Utilized
# AI, Blockchain, ERP         610
# AI, ERP, Robotics           112
# ERP, JIT, Robotics           28
# AI, Blockchain, Robotics     27
# Name: count, dtype: int64

# %%
# The most frequnte technology used by the compnay
technology_counts = df['Technology Utilized'].str.split(', ').explode().value_counts()
display(technology_counts)
# Out:
# Technology Utilized
# ERP           750
# AI            749
# Blockchain    637
# Robotics      167
# JIT            28
# Name: count, dtype: int64

# %%
# Most frequent technology paires
technology_pairs = df['Technology Utilized'].apply(lambda x: list(combinations(sorted(x.split(', ')), 2))).explode().value_counts()
display(technology_pairs)
# Out:
# Technology Utilized
# (AI, ERP)                 722
# (AI, Blockchain)          637
# (Blockchain, ERP)         610
# (ERP, Robotics)           140
# (AI, Robotics)            139
# (ERP, JIT)                 28
# (JIT, Robotics)            28
# (Blockchain, Robotics)     27
# Name: count, dtype: int64

# %%
# plt.figure(figsize=(25,7))

# plt.subplot(1, 3, 1)
# bp1 = sns.barplot(x= df['Technology Utilized'].value_counts().index , y=df['Technology Utilized'].value_counts().values)
# bp1.set(xticklabels=list(df['Technology Utilized'].value_counts().index))
# bp1.set_xticklabels(bp1.get_xticklabels(), rotation=-70, size = 12)
# plt.title("Technology Utilized")

# # plt.subplot(1, 3, 2)

# # bp2 = sns.barplot(x = technology_pairs.index.values , y = technology_pairs.values)
# # bp2.set(xticklabels=list(technology_pairs.index.values))
# # bp2.set_xticklabels(bp2.get_xticklabels(), rotation=-50, size = 12)
# # plt.title("Most frequent Technology Paires")


# plt.subplot(1, 3, 3)
# bp3= sns.barplot(x= technology_counts.index.values , y= technology_counts.values)
# bp3.set(xticklabels=list(technology_counts.index.values))
# bp3.set_xticklabels(bp3.get_xticklabels(), rotation=-80, size = 12)
# plt.title("Most Frequent Technology")


# plt.show()

# %% [markdown]
# `This figure show that AI, ERP and Blockchain are the most used technologyes`

# %%
# df['Technology Utilized'] = df['Technology Utilized'].str.split(', ')
# technology_dummies = df['Technology Utilized'].str.join('|').str.get_dummies()
# df = df.join(technology_dummies)

# %%
# df.drop("Technology Utilized" ,axis=1,inplace=True)

# %%
for feat in  ["SCM Practices","Supply Chain Agility","Supply Chain Integration Level","Supply Chain Complexity Index","Supplier Collaboration Level"]:
    display(df[feat].value_counts(normalize= False))
    print("-"*20)
# Out:
# SCM Practices
# Agile SCM                      263
# Lean Manufacturing             248
# Vendor Managed Inventory       122
# Sustainable SCM                 49
# Demand-Driven SCM               46
# Just-In-Time                    26
# Cross-Docking                   14
# Efficient Consumer Response      9
# Name: count, dtype: int64
# --------------------
# Supply Chain Agility
# High      669
# Medium    108
# Name: count, dtype: int64
# --------------------
# Supply Chain Integration Level
# High      642
# Medium    135
# Name: count, dtype: int64
# --------------------
# Supply Chain Complexity Index
# Medium    444
# High      196
# Low       137
# Name: count, dtype: int64
# --------------------
# Supplier Collaboration Level
# High      555
# Medium    222
# Name: count, dtype: int64
# --------------------

# %% [markdown]
# * `Agile SCM, Lean Manufacturing and Vendor Managed Inventory is the most used SCM practices.`
# * `Almost companies in the data have high 'Supply power'.`

# %%
# Checking the Supply Cahin Risk for the supply power variables.
supply_powre = ["Supply Chain Agility","Supply Chain Integration Level","Supply Chain Complexity Index","Supplier Collaboration Level"]


    
figure, axis = plt.subplots(2, 2, figsize=(12, 8))
plt.subplots_adjust(hspace=0.25, wspace=0.3)

for i, column_name in enumerate(supply_powre[:]):
    row = i// 2
    col = i % 2
    sns.barplot(ax=axis[row, col], x=df[column_name], y= df[Target], palette=["#4c72b0", "#55a868", "#c44e52"])
    axis[row, col].set_title(column_name)
plt.show()

# %% [markdown]
# * `The Supply Chain Risk is the high for the supply power variables with medium and low quality , Thus these variables may have high predictive preformance `

# %% [markdown]
# ### **Numerical features**

# %%
# Distributions of the numerical features
figure, axis = plt.subplots(5, 4, figsize=(25, 29))
plt.subplots_adjust(hspace=0.25, wspace=0.3)

for i, column_name in enumerate(num):
    row = i//4
    col = i % 4
    sns.kdeplot(ax=axis[row, col], x=df[column_name], linewidth=2, fill=True) # hue=df['Category'], common_norm=False 

    axis[row, col].set_title(column_name)
plt.show()

# %% [markdown]
# * **Total Implementation Cost**

# %%
df['Total Implementation Cost'].describe()
# Out:
# count            777.00
# mean        20125944.12
# std        999059512.38
# min     -27779684291.50
# 25%         32179203.60
# 50%         55395427.00
# 75%         81200126.00
# max        109885632.00
# Name: Total Implementation Cost, dtype: float64

# %% [markdown]
# `Total Implementation Cost can not take a nagetive values!`

# %%
# Drop the index with negative value.
df.drop(df.loc[df['Total Implementation Cost'] <= -27779684291.50].index , axis=0, inplace=True)

# %% [markdown]
# ### Outliers Analysis

# %%
# Boxplot for numerical features
figure, axis = plt.subplots(5, 4, figsize=(25, 29))
plt.subplots_adjust(hspace=0.25, wspace=0.3)

for i, column_name in enumerate(num[:]):
    row = i//4
    col = i % 4
    bp = sns.boxplot(ax=axis[row, col], x=df[column_name], color= 'lightgreen')
#     bp.set(xticklabels=[])
    #bp.set_xticklabels(bp.get_xticklabels(), rotation=90, size = 7)
    axis[row, col].set_title(column_name)
plt.show()

# %% [markdown]
# * `After checking the exterem outliers and go back to domain knowldege it's normal nuature of these companies.`

# %% [markdown]
# ## **Bivariate Analysis**

# %% [markdown]
# ### **Categorical Chi_Squar Test of Independence**

# %%
# Supply chain management practices VS Technology utilized by the companies 

contingency_table1 = pd.crosstab(df['SCM Practices'], df['Technology Utilized'],normalize = True)
hm = sns.heatmap(contingency_table1, annot=True, cmap="YlGnBu")
hm.set(xticklabels=list(contingency_table1.columns))
hm.set_xticklabels(hm.get_xticklabels(), rotation=-50, size = 12)
plt.show() 

# display(pg.chi2(contingency_table))
expected, observed, stats = pg.chi2_independence(df, x='SCM Practices', y='Technology Utilized')
display(stats)
# Out:
#                  test  lambda  chi2   dof  pval  cramer  power
# 0             pearson    1.00 57.26 21.00  0.00    0.16   0.74
# 1        cressie-read    0.67 53.01 21.00  0.00    0.15   0.69
# 2      log-likelihood    0.00 51.46 21.00  0.00    0.15   0.68
# 3       freeman-tukey   -0.50   NaN 21.00   NaN     NaN    NaN
# 4  mod-log-likelihood   -1.00   inf 21.00  0.00     inf    NaN
# 5              neyman   -2.00   NaN 21.00   NaN     NaN    NaN

# %% [markdown]
# * `There is a significant realtion btween the SCM practices and Technology Uitlized variables`

# %%
# Supply Chain Agility VS Supply Chain Integration Level

sns.heatmap(pd.crosstab(df["Supply Chain Agility"] , df["Supply Chain Integration Level"],normalize=True) , annot=True, cmap="YlGnBu")
plt.show()
expected, observed, stats = pg.chi2_independence(df, x="Supply Chain Agility", y="Supply Chain Integration Level")
display(stats)
# Out:
#                  test  lambda     chi2  dof  pval  cramer  power
# 0             pearson    1.00   589.05 1.00  0.00    0.87   1.00
# 1        cressie-read    0.67   514.54 1.00  0.00    0.81   1.00
# 2      log-likelihood    0.00   481.54 1.00  0.00    0.79   1.00
# 3       freeman-tukey   -0.50   586.85 1.00  0.00    0.87   1.00
# 4  mod-log-likelihood   -1.00  1029.87 1.00  0.00    1.15   1.00
# 5              neyman   -2.00 16111.07 1.00  0.00    4.56   1.00

# %% [markdown]
# * `There is a significant realtion btween the Supply Chain Agility and Supply Chain Integration Level`

# %%
# Supply Chain Complexity Index VS Supplier Collaboration Level

sns.heatmap(pd.crosstab(df["Supply Chain Complexity Index"] , df["Supplier Collaboration Level"],normalize=True) , annot=True, cmap="YlGnBu")
plt.show()
expected, observed, stats = pg.chi2_independence(df, x="Supply Chain Complexity Index", y="Supplier Collaboration Level")
display(stats)
# Out:
#                  test  lambda   chi2  dof  pval  cramer  power
# 0             pearson    1.00 232.52 2.00  0.00    0.55   1.00
# 1        cressie-read    0.67 246.27 2.00  0.00    0.56   1.00
# 2      log-likelihood    0.00 313.52 2.00  0.00    0.64   1.00
# 3       freeman-tukey   -0.50    NaN 2.00   NaN     NaN    NaN
# 4  mod-log-likelihood   -1.00    inf 2.00  0.00     inf    NaN
# 5              neyman   -2.00    NaN 2.00   NaN     NaN    NaN

# %% [markdown]
# * `There is a significant realtion btween the Supply Chain Complexity Index and Supplier Collaboration Level`
#
# * **Note: There is a redandancy in the supply power variablec, which is not a good thing!**

# %% [markdown]
# ### **Pairwise Correlation with the Target variable and for numerical variables**

# %%
# correlation with the target variable Operationl Efficincy Score
df[num].corrwith(df[Target])
# Out:
# Supplier Count                          -0.07
# Inventory Turnover Ratio                -0.04
# Lead Time (days)                         0.85
# Order Fulfillment Rate (%)              -0.86
# Customer Satisfaction (%)               -0.10
# Supplier Lead Time Variability (days)    0.79
# Inventory Accuracy (%)                  -0.56
# Transportation Cost Efficiency (%)      -0.71
# Cost of Goods Sold (COGS)               -0.40
# Operational Efficiency Score            -0.23
# Revenue Growth Rate out of (15)         -0.62
# Supply Chain Risk (%)                    1.00
# Supply Chain Resilience Score           -0.87
# Supplier Relationship Score             -0.75
# Total Implementation Cost               -0.02
# Carbon Emissions (kg CO2e)              -0.00
# Recycling Rate (%)                      -0.00
# Energy Consumption (MWh)                -0.00
# Use of Renewable Energy (%)              0.00
# Green Packaging Usage (%)                0.02
# dtype: float64

# %%
def highlight_high_corr(val):
    color = 'lightblue' if (abs(val) >= 0.60) and val != 1 else ''
    return f'background-color: {color}'

display(df[num].corr().style.applymap(highlight_high_corr))
correlated_features = [(df[num].corr().index[i], df[num].corr().columns[j], df[num].corr().iloc[i, j] * 100) 
                       for i in range(len(df[num].corr())) 
                       for j in range(i+1, len(df[num].corr())) 
                       if df[num].corr().iloc[i, j] >= 0.60]
display(set(correlated_features))
# Out:
# <style type="text/css">
# ...

# %% [markdown]
# * `Carbon Emissions (kg CO2e) and Energy Consumption (MWh) are the same variable since r = 100.0`

# %%
df.drop("Energy Consumption (MWh)" , axis=1, inplace=True)

# %% [markdown]
# # More Data for training with SDV library

# %%
from sdv.metadata import SingleTableMetadata

metadata = SingleTableMetadata()

# %%
metadata.detect_from_dataframe(df)

metadata.update_columns(
    column_names=['Company Name'],
    sdtype='id',
)


metadata.set_primary_key(column_name='Company Name')

python_dict = metadata.to_dict()


python_dict
# Out:
# {'METADATA_SPEC_VERSION': 'SINGLE_TABLE_V1',
#  'columns': {'Company Name': {'sdtype': 'id'},
#   'SCM Practices': {'sdtype': 'categorical'},
#   'Technology Utilized': {'sdtype': 'categorical'},
#   'Supply Chain Agility': {'sdtype': 'categorical'},
#   'Supply Chain Integration Level': {'sdtype': 'categorical'},
#   'Supply Chain Complexity Index': {'sdtype': 'categorical'},
#   'Supplier Collaboration Level': {'sdtype': 'categorical'},
#   'Supplier Count': {'sdtype': 'numerical'},
#   'Inventory Turnover Ratio': {'sdtype': 'numerical'},
#   'Lead Time (days)': {'sdtype': 'numerical'},
#   'Order Fulfillment Rate (%)': {'sdtype': 'numerical'},
#   'Customer Satisfaction (%)': {'sdtype': 'numerical'},
#   'Supplier Lead Time Variability (days)': {'sdtype': 'numerical'},
#   'Inventory Accuracy (%)': {'sdtype': 'numerical'},
#   'Transportation Cost Efficiency (%)': {'sdtype': 'numerical'},
#   'Cost of Goods Sold (COGS)': {'sdtype': 'numerical'},
# ...

# %%
from sdv.metadata import SingleTableMetadata
from sdv.lite import SingleTablePreset

metadata_obj = SingleTableMetadata.load_from_dict(python_dict)



from sdv.single_table import GaussianCopulaSynthesizer

synthesizer = GaussianCopulaSynthesizer(metadata_obj)


synthesizer.fit(df)

# %%
synthetic_data = synthesizer.sample(
    num_rows=100000,
)

# %%
synthetic_data.shape
# Out:
# (100000, 26)

# %%
from sdv.evaluation.single_table import run_diagnostic

diagnostic_report = run_diagnostic(
    real_data=df,
    synthetic_data=synthetic_data,
    metadata=metadata)
# Out:
# Generating report ...
#
# (1/2) Evaluating Data Validity: |█████████████| 26/26 [00:00<00:00, 163.40it/s]|
# Data Validity Score: 100.0%
#
# (2/2) Evaluating Data Structure: |███████████████| 1/1 [00:00<00:00, 74.54it/s]|
# Data Structure Score: 100.0%
#
# Overall Score (Average): 100.0%

# %%
from sdv.evaluation.single_table import evaluate_quality

quality_report = evaluate_quality(
    real_data=df,
    synthetic_data=synthetic_data,
    metadata=metadata)
# Out:
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████████| 26/26 [00:00<00:00, 44.13it/s]|
# Column Shapes Score: 82.46%
#
# (2/2) Evaluating Column Pair Trends: |███████| 325/325 [00:15<00:00, 21.55it/s]|
# Column Pair Trends Score: 84.45%
#
# Overall Score (Average): 83.46%

# %%
Target
# Out:
# 'Supply Chain Risk (%)'

# %%
# from sdv.evaluation.single_table import get_column_plot

# fig = get_column_plot(
#     real_data=df,
#     synthetic_data=synthetic_data,
#     metadata=metadata,
#     column_name='Supply Chain Risk (%)'
# )
    
# fig.show()

# %%
df_new = pd.concat([df , synthetic_data] , axis=0)

# %%
df_new.drop("Company Name",axis=1 , inplace=True)

# %%
df_new.shape
# Out:
# (100776, 26)

# %% [markdown]
# # Data spliting

# %%
train , test = train_test_split(df_new, test_size = 0.30, random_state=42, shuffle=True)
train.shape , test.shape
# Out:
# ((70543, 25), (30233, 25))

# %% [markdown]
# # Feature Engineering

# %%
#  Create new features for predicting supply chain risk

for df in [train , test]:   
    
    # Calculate the Adjusted Lead Time Index
    
    df['Adjusted Lead Time Index'] = 0.6 * df['Lead Time (days)'] + 0.4 * df['Supplier Lead Time Variability (days)']
        
    
    df['Collaborative Resilience Index'] = df['Supply Chain Resilience Score'] * df['Supplier Relationship Score']
    
    
    df['Fulfillment_Transport_Interaction'] = df['Order Fulfillment Rate (%)'] * df['Transportation Cost Efficiency (%)']
    
    df['Combined_Supplier_Score'] = df['Supply Chain Resilience Score'] + df['Supplier Relationship Score']

# %%
num = list(df.select_dtypes(exclude="O").columns)
df[num].corrwith(df[Target])
# Out:
# Supplier Count                          -0.05
# Inventory Turnover Ratio                -0.07
# Lead Time (days)                         0.85
# Order Fulfillment Rate (%)              -0.85
# Customer Satisfaction (%)               -0.11
# Supplier Lead Time Variability (days)    0.83
# Inventory Accuracy (%)                  -0.16
# Transportation Cost Efficiency (%)      -0.02
# Cost of Goods Sold (COGS)               -0.34
# Operational Efficiency Score            -0.25
# Revenue Growth Rate out of (15)         -0.53
# Supply Chain Risk (%)                    1.00
# Supply Chain Resilience Score           -0.87
# Supplier Relationship Score             -0.75
# Total Implementation Cost               -0.02
# Carbon Emissions (kg CO2e)               0.01
# Recycling Rate (%)                      -0.01
# Use of Renewable Energy (%)             -0.00
# Green Packaging Usage (%)                0.01
# Adjusted Lead Time Index                 0.87
# ...

# %% [markdown]
# # Data Preprocessing

# %%
cat= [i for i in df.select_dtypes(include="O").columns if i in selected_features]
num = [i for i in df.select_dtypes(exclude="O").columns if i in selected_features]

# %%
le = LabelEncoder()
df = pd.concat([train, test])
for f in cat:
    le.fit(df[f])
    train[f] = le.transform(train[f])
    test[f] = le.transform(test[f])

# %%
X_test = test[selected_features]
y_test = test[Target]

# %% [markdown]
# # Feature Selection

# %%
from sklearn.feature_selection import RFE

model1 = XGBRegressor(random_state=42)
model2 = LinearRegression()

X = train.drop(Target, axis=1)
y = train[Target]
# Initialize RFE with the model and select the top 7 features

selector_xgb = RFE(model1, n_features_to_select=10, step=1)
selector_xgb = selector.fit(X, y)

selector_lr = RFE(model2, n_features_to_select=10, step=1)
selector_lr = selector.fit(X, y)
# Print the selected features
# Get the boolean mask indicating selected features
selected_mask1 = selector_xgb.support_
selected_mask2 = selector_lr.support_


# Use the mask to filter the column names from the DataFrame
selected_features_xgb = X.columns[selected_mask1].tolist()
selected_features_lr = X.columns[selected_mask2].tolist()


print("Selected features XGB:", selected_features_xgb)
print("Selected features LR:", selected_features_lr)
# Out:
# Selected features XGB: ['Supplier Collaboration Level', 'Order Fulfillment Rate (%)', 'Inventory Accuracy (%)', 'Cost of Goods Sold (COGS)', 'Revenue Growth Rate out of (15)', 'Supply Chain Resilience Score', 'Adjusted Lead Time Index', 'Collaborative Resilience Index', 'Fulfillment_Transport_Interaction', 'Combined_Supplier_Score']
# Selected features LR: ['Supplier Collaboration Level', 'Order Fulfillment Rate (%)', 'Inventory Accuracy (%)', 'Cost of Goods Sold (COGS)', 'Revenue Growth Rate out of (15)', 'Supply Chain Resilience Score', 'Adjusted Lead Time Index', 'Collaborative Resilience Index', 'Fulfillment_Transport_Interaction', 'Combined_Supplier_Score']

# %% [markdown]
# # Modeling

# %%
from sklearn.model_selection import KFold

# X = train[selected_features]
# y = train['Supply Chain Risk (%)']

preprocessor1 = ColumnTransformer(
    transformers=[
        ('cat', OneHotEncoder(),cat),
        ('num', StandardScaler(),num)
    ])

preprocessor2 = ColumnTransformer(
    transformers=[
        ('cat', OneHotEncoder(),cat),
        ('num', StandardScaler(),num)
    ])

lr = LinearRegression()
xgb = XGBRegressor(random_state=42)

pipeline1 = Pipeline(steps=[("preprocessor1", preprocessor1)
                            ,('model', lr)])

pipeline2 = Pipeline(steps=[("preprocessor2", preprocessor2)
                            ,('model',  xgb)])
# rf = RandomForestRegressor(random_state=42,criterion='squared_error')
lr = LinearRegression()
xgb = XGBRegressor(random_state=42)

train_scores = []
val_scores = []

kf = KFold(n_splits=5, shuffle=True , random_state=42)
for i , pipeline in enumerate([pipeline1 , pipeline2]):
    print(f"Model => {pipeline}")
    if i == 0 :
        X= train[selected_features_lr]
        y=train[Target]
    else:
        X= train[selected_features_xgb]
        y=train[Target]

    for fold, (train_index, val_index) in enumerate(kf.split(X,y)):

        print(f"Fold {fold +1}")

        X_train , y_train = X.iloc[train_index], y.iloc[train_index]
        X_val , y_val = X.iloc[val_index], y.iloc[val_index]

        pipeline.fit(X_train,y_train)

        train_pred = pipeline.predict(X_train)
        train_scores.append(r2_score(y_train, train_pred))
        print(f"train mean squar error => {mean_squared_error(y_train,train_pred):.5f}")

        val_pred = pipeline.predict(X_val)
        val_scores.append(r2_score(y_val, val_pred))

        print(f"validation mean squar error => {mean_squared_error(y_val ,val_pred):.5f}")
        print("_"*20)



    print(f"Mean Train score :{np.mean(train_scores):.5f}")
    print(f"Mean validation score :{np.mean(val_scores):.5f}")

    print("\n TEST PREDICTION\t")
    print("_"*20)


    test_pred = pipeline.predict(X_test)

    print(f"Test mean squar error => {mean_squared_error(y_test,test_pred):.5f}")
    print(f"Test R2 Score => {r2_score(y_test, test_pred):.5f}")
    
    print("#"*25)
# Out:
# Model => Pipeline(steps=[('preprocessor1',
#                  ColumnTransformer(transformers=[('cat', OneHotEncoder(), []),
#                                                  ('num', StandardScaler(),
#                                                   ['Supplier Collaboration '
#                                                    'Level',
#                                                    'Order Fulfillment Rate (%)',
#                                                    'Inventory Accuracy (%)',
#                                                    'Cost of Goods Sold (COGS)',
#                                                    'Revenue Growth Rate out of '
#                                                    '(15)',
#                                                    'Supply Chain Resilience '
#                                                    'Score',
#                                                    'Adjusted Lead Time Index',
# ...

# %%
#Plot the LGBM Features Importances
def plotImp(model, X , num = 20, fig_size = (40, 20)):
    feature_imp = pd.DataFrame({'Value':model.feature_importances_,'Feature':X.columns})
    plt.figure(figsize=fig_size)
    sns.set(font_scale = 5)
    sns.barplot(x="Value", y="Feature", data=feature_imp.sort_values(by="Value", 
                                                        ascending=False)[0:num])
    plt.title('RandomForest Features (avg over folds)')
    plt.tight_layout()
#     plt.savefig('lgbm_importances-01.png')
    plt.show()

# %%
plotImp(xgb,X)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[136], line 1
# ----> 1 plotImp(pipeline2.model,X)
#
# AttributeError: 'Pipeline' object has no attribute 'model'

# %% [markdown]
# ## Model selection

# %%
# preprocessor1 = ColumnTransformer(
#     transformers=[
#         ('num', MinMaxScaler(), X_num ),
#         ('cat', OneHotEncoder(),X_cat )
#     ])

# preprocessor2 = ColumnTransformer(
#     transformers=[
#         ('cat', OneHotEncoder(), X_cat),
#         ('num', MinMaxScaler(), X_num),
#         ('num_pca', PCA(n_components=10), X_num)
#     ])
# preprocessor3 = ColumnTransformer(
#     transformers=[
#         ('cat', StandardScaler(), X_cat),
#         ('num_pca', PCA(n_components=10), X_num)
#     ])

# # Different models to try
# models = {
#     'random_forest': RandomForestRegressor(random_state=42,criterion='squared_error'),
#     "xgboost": XGBRegressor(random_state=42),
#     'linearRegressi': LinearRegression()
# }

# # Iterate over models and evaluate using cross-validation
# for model_name, model in models.items():
#     # Create a pipeline with the preprocessor and the current model
#     pipeline1 = Pipeline(steps=[('model', model)])
#     pipeline2 = Pipeline(steps=[('preprocessor2', preprocessor2),
#                                ('model', model)])
#     pipeline3 = Pipeline(steps=[('preprocessor3', preprocessor3),
#                                ('model', model)])
    
#     # Evaluate the model using cross-validation
#     scores1 = cross_val_score(pipeline1, X_train, y_train, cv=5, scoring='r2')
#     scores2 = cross_val_score(pipeline2, X_train, y_train, cv=5, scoring='r2')
#     scores3 = cross_val_score(pipeline3, X_train, y_train, cv=5, scoring='r2')
    
#     print(f"Model: {model_name},\nR2 Score1: {scores1.mean():.3f},\nStd1: {scores1.std():.3f} ,\n scores: {scores1}")
#     print(f"Model: {model_name},\nR2 Score2: {scores2.mean():.3f},\nStd2: {scores2.std():.3f},\n scores: {scores2}")
#     print(f"Model: {model_name},\nR2 Score3: {scores3.mean():.3f},\nStd3: {scores3.std():.3f},\n scores: {scores3}")
